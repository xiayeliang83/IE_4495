# %% [markdown]
# <a href="https://colab.research.google.com/github/yongzhiqu/IE_4495/blob/master/CH01_SEC04_1_Linear.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams.update({'font.size': 18})

x = 3 # True slope
a = np.arange(-2,2,0.25)
print(a)
a = a.reshape(-1, 1)
print(a)
b = x*a + np.random.randn(*a.shape) # Add noise

plt.plot(a, x*a, Color='k', LineWidth=2, label='True line') # True relationship
plt.plot(a, b, 'x', Color='r', MarkerSize = 10, label='Noisy data') # Noisy measurements

U, S, VT = np.linalg.svd(a,full_matrices=False)
xtilde = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b # Least-square fit

plt.plot(a,xtilde * a,'--',Color='b',LineWidth=4, label='Regression line')

plt.xlabel('a')
plt.ylabel('b')

plt.grid(linestyle='--')
plt.legend()
plt.show()
# Out:
# [-2.   -1.75 -1.5  -1.25 -1.   -0.75 -0.5  -0.25  0.    0.25  0.5   0.75
#   1.    1.25  1.5   1.75]
# [[-2.  ]
#  [-1.75]
#  [-1.5 ]
#  [-1.25]
#  [-1.  ]
#  [-0.75]
#  [-0.5 ]
#  [-0.25]
#  [ 0.  ]
#  [ 0.25]
#  [ 0.5 ]
#  [ 0.75]
#  [ 1.  ]
#  [ 1.25]
#  [ 1.5 ]
#  [ 1.75]]

# %%
# Three methods of computing regression

xtilde1 = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b
xtilde2 = np.linalg.pinv(a) @ b
print(xtilde1)
print(xtilde2)



# The third method is specific to Matlab:
# xtilde3 = regress(b,a)
# Out:
# [[2.83520606]]
# [[2.83520606]]
