# %% [markdown]
# <a href="https://colab.research.google.com/github/yongzhiqu/IE_4495/blob/master/CH01_SEC04_2_Cement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
plt.rcParams['figure.figsize'] = [8, 8]
plt.rcParams.update({'font.size': 18})

# Load dataset
A = np.loadtxt(os.path.join('/content/drive/MyDrive/Colab Notebooks','DATA','hald_ingredients.csv'),delimiter=',')
b = np.loadtxt(os.path.join('/content/drive/MyDrive/Colab Notebooks','DATA','hald_heat.csv'),delimiter=',')
print(A)
print(b)

# Solve Ax=b using SVD
U, S, VT = np.linalg.svd(A,full_matrices=0)
x = VT.T @ np.linalg.inv(np.diag(S)) @ U.T @ b

plt.plot(b, Color='k', LineWidth=2, label='Heat Data') # True relationship
plt.plot(A@x, '-o', Color='r', LineWidth=1.5, MarkerSize=6, label='Regression')
plt.legend()
plt.show()

print(x)
# Out:
# [[ 7. 26.  6. 60.]
#  [ 1. 29. 15. 52.]
#  [11. 56.  8. 20.]
#  [11. 31.  8. 47.]
#  [ 7. 52.  6. 33.]
#  [11. 55.  9. 22.]
#  [ 3. 71. 17.  6.]
#  [ 1. 31. 22. 44.]
#  [ 2. 54. 18. 22.]
#  [21. 47.  4. 26.]
#  [ 1. 40. 23. 34.]
#  [11. 66.  9. 12.]
#  [10. 68.  8. 12.]]
# [ 78.5  74.3 104.3  87.6  95.9 109.2 102.7  72.5  93.1 115.9  83.8 113.3
#  109.4]
# [2.19304602 1.15332597 0.75850914 0.48631933]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Alternative Methods:

# The first alternative is specific to Matlab:
# x = regress(b,A)

# Alternative 2:
x = np.linalg.pinv(A)*b
print(x)
# Out:
# [[-1.51874907 -1.30978528  0.52634518  1.38763652 -3.01676834  0.9327376
#   -1.62884386  0.94304243 -0.80468849  6.42498435  1.10344448  0.25522057
#   -1.10153007]
#  [ 0.31780639  0.1280411   0.19000428 -0.31636354  0.94699903  0.06902433
#    0.60287169 -0.48197243  0.18484056 -1.09100025 -0.49104022  0.37715789
#    0.71695715]
#  [-2.04657526 -0.48525373 -0.27204125  0.26857647 -3.15197748  0.13202941
#    0.0827754   2.05360987  0.66628639  2.69738265  2.58672993 -0.32242966
#   -1.45060359]
#  [ 0.87363684  0.49965163 -0.06801851  0.28003361  0.71379413 -0.11544141
#   -0.33115862 -0.07961185 -0.12191576 -0.60631343 -0.28447275 -0.24916753
#   -0.02469701]]

# %%
x = (A_transpose*A)^-1*A_transpose*b
